# %%
import pandas as pd

# %%
# !dir
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is B233-0680
#
#  Directory of C:\data science\myntra
#
# 06-12-2023  19:02    <DIR>          .
# 06-12-2023  11:03    <DIR>          ..
# 06-12-2023  11:26    <DIR>          .ipynb_checkpoints
# 06-12-2023  19:00         2,111,183 eda-store-myntra.ipynb
# 06-12-2023  19:02           209,162 myntra data analysis.ipynb
# 06-12-2023  11:03       130,582,602 Myntra Fasion Clothing.csv
#                3 File(s)    132,902,947 bytes
#                3 Dir(s)  227,344,396,288 bytes free

# %%
myntra=pd.read_csv("Myntra Fasion Clothing.csv")
# Out:
# C:\Users\91994\AppData\Local\Temp\ipykernel_3912\3635243604.py:1: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   myntra=pd.read_csv("Myntra Fasion Clothing.csv")

# %%
myntra
# Out:
#                                                       URL  Product_id  \
# 0       https://www.myntra.com/jeans/roadster/roadster...     2296012
# 1       https://www.myntra.com/track-pants/locomotive/...    13780156
# 2       https://www.myntra.com/shirts/roadster/roadste...    11895958
# 3       https://www.myntra.com/shapewear/zivame/zivame...     4335679
# 4       https://www.myntra.com/tshirts/roadster/roadst...    11690882
# ...                                                   ...         ...
# 526559  https://www.myntra.com/sweaters/hm/hm-women-be...    16929990
# 526560  https://www.myntra.com/jackets/hm/hm-women-bla...    16026012
# 526561  https://www.myntra.com/dresses/250-designs/250...    17654114
# 526562  https://www.myntra.com/dresses/masaba/masaba-w...    12508700
# 526563  https://www.myntra.com/tshirts/jockey/jockey-w...    17856544
#
#           BrandName               Category Individual_category  \
# ...

# %%
column_to_drop = 'URL'
myntra = myntra.drop(column_to_drop, axis=1)

# %%
myntra
# Out:
#         Product_id    BrandName               Category Individual_category  \
# 0          2296012     Roadster            Bottom Wear               jeans
# 1         13780156   LOCOMOTIVE            Bottom Wear         track-pants
# 2         11895958     Roadster                Topwear              shirts
# 3          4335679       Zivame  Lingerie & Sleep Wear           shapewear
# 4         11690882     Roadster                Western             tshirts
# ...            ...          ...                    ...                 ...
# 526559    16929990          H&M                Western            sweaters
# 526560    16026012          H&M                Western             jackets
# 526561    17654114  250 DESIGNS                Western             dresses
# 526562    12508700       Masaba                Western             dresses
# 526563    17856544       Jockey                Western             tshirts
#
# ...

# %%
myntra.loc[:,"Description"]
# Out:
# 0         roadster men navy blue slim fit mid rise clean...
# 1         locomotive men black  white solid slim fit tra...
# 2         roadster men navy white  black geometric print...
# 3         zivame women black saree shapewear zi3023core0...
# 4         roadster women white solid v neck pure cotton ...
#                                 ...
# 526559             hm women beige oversized cashmere jumper
# 526560          hm women black water repellent parka jacket
# 526561                   250 designs blue lace sheath dress
# 526562             masaba women yellow printed a line dress
# 526563           jockey women blue extended sleeves t shirt
# Name: Description, Length: 526564, dtype: object

# %%
myntra.isnull().sum()
# Out:
# Product_id                    0
# BrandName                     0
# Category                      0
# Individual_category           0
# category_by_Gender            0
# Description                   0
# DiscountPrice (in Rs)    193158
# OriginalPrice (in Rs)         0
# DiscountOffer             74306
# SizeOption                    0
# Ratings                  336152
# Reviews                  336152
# dtype: int64

# %%
myntra=myntra.fillna(0)

# %%
myntra.isnull().sum()
# Out:
# Product_id               0
# BrandName                0
# Category                 0
# Individual_category      0
# category_by_Gender       0
# Description              0
# DiscountPrice (in Rs)    0
# OriginalPrice (in Rs)    0
# DiscountOffer            0
# SizeOption               0
# Ratings                  0
# Reviews                  0
# dtype: int64

# %%
myntra.shape
# Out:
# (526564, 12)

# %% [markdown]
# myntra.duplicated().sum()

# %%
table = pd.DataFrame({
    'Unique':myntra.nunique(),
    'Null':myntra.isna().sum(),
    'NullPercent':myntra.isna().sum() / len(myntra),
    'Type':myntra.dtypes.values
})
display(table)
# Out:
#                        Unique  Null  NullPercent     Type
# Product_id             526564     0          0.0    int64
# BrandName                2088     0          0.0   object
# Category                    8     0          0.0   object
# Individual_category        92     0          0.0   object
# category_by_Gender          2     0          0.0   object
# Description            429766     0          0.0   object
# DiscountPrice (in Rs)    4456     0          0.0  float64
# OriginalPrice (in Rs)    4914     0          0.0  float64
# DiscountOffer            1419     0          0.0   object
# SizeOption               3588     0          0.0   object
# Ratings                    42     0          0.0  float64
# Reviews                  1000     0          0.0  float64

# %%
myntra['BrandName'] = myntra['BrandName'].apply(lambda t: t.lower())
myntra['BrandName'] = myntra['BrandName'].apply(lambda t: t.capitalize())

# %%
myntra["BrandName"]
# Out:
# 0            Roadster
# 1          Locomotive
# 2            Roadster
# 3              Zivame
# 4            Roadster
#              ...
# 526559            H&m
# 526560            H&m
# 526561    250 designs
# 526562         Masaba
# 526563         Jockey
# Name: BrandName, Length: 526564, dtype: object

# %%
myntra
# Out:
#         Product_id    BrandName               Category Individual_category  \
# 0          2296012     Roadster            Bottom Wear               jeans
# 1         13780156   Locomotive            Bottom Wear         track-pants
# 2         11895958     Roadster                Topwear              shirts
# 3          4335679       Zivame  Lingerie & Sleep Wear           shapewear
# 4         11690882     Roadster                Western             tshirts
# ...            ...          ...                    ...                 ...
# 526559    16929990          H&m                Western            sweaters
# 526560    16026012          H&m                Western             jackets
# 526561    17654114  250 designs                Western             dresses
# 526562    12508700       Masaba                Western             dresses
# 526563    17856544       Jockey                Western             tshirts
#
# ...

# %%
myntra["Individual_category"] = myntra["Individual_category"].apply(lambda t: t.lower())
myntra["Individual_category"] = myntra["Individual_category"].apply(lambda t: t.capitalize())

# %%
myntra
# Out:
#         Product_id    BrandName               Category Individual_category  \
# 0          2296012     Roadster            Bottom Wear               Jeans
# 1         13780156   Locomotive            Bottom Wear         Track-pants
# 2         11895958     Roadster                Topwear              Shirts
# 3          4335679       Zivame  Lingerie & Sleep Wear           Shapewear
# 4         11690882     Roadster                Western             Tshirts
# ...            ...          ...                    ...                 ...
# 526559    16929990          H&m                Western            Sweaters
# 526560    16026012          H&m                Western             Jackets
# 526561    17654114  250 designs                Western             Dresses
# 526562    12508700       Masaba                Western             Dresses
# 526563    17856544       Jockey                Western             Tshirts
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
features = ["DiscountPrice (in Rs)","OriginalPrice (in Rs)"]
for data in features:
    sns.boxplot(x=myntra[data])
    plt.tight_layout()
    plt.show()

# %%
myntra.columns
# Out:
# Index(['Product_id', 'BrandName', 'Category', 'Individual_category',
#        'category_by_Gender', 'Description', 'DiscountPrice (in Rs)',
#        'OriginalPrice (in Rs)', 'DiscountOffer', 'SizeOption', 'Ratings',
#        'Reviews'],
#       dtype='object')

# %%
columns = ["Reviews","Ratings","OriginalPrice (in Rs)","DiscountPrice (in Rs)"]
for data in columns:
    plt.figure(figsize=(18,7))
    sns.histplot(x=myntra[data])
    plt.xticks(fontsize=14)
#     plt.tight_layout()
    plt.show()

# %%
columns = ["Reviews","Ratings","DiscountPrice (in Rs)","OriginalPrice (in Rs)"]

for i in columns:
    plt.figure(figsize=(14,7))
    sns.kdeplot(x=myntra[i], hue=myntra["category_by_Gender"])
    plt.xticks(fontsize=14)
    plt.tight_layout()
    plt.show()

# %%
plt.figure(figsize=(14,7))
myntra['category_by_Gender'].value_counts().plot.pie(autopct='%.2f', textprops={'size':14})
# Out:
# <Axes: ylabel='category_by_Gender'>

# %%
columns = ['BrandName','DiscountOffer', 'SizeOption', 'Ratings']

plt.figure(figsize=(10,20))
for i, col in enumerate(columns):
    axes = plt.subplot(4,2, i + 1)
    sns.countplot(y=myntra[col], order=myntra[col].value_counts().index[0:10], palette='Spectral')
    plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
